# %% [markdown]
# ## **Install Packages:**

# %%
# %%capture --no-stderr
# %pip install -qU langchain-google-genai langchain_core

# %% [markdown]
# ## **Import Gemini Key:**

# %%
# For Colab, use this:
from google.colab import userdata
GEMINI_API_KEY = userdata.get("GEMINI_API_KEY")

# %% [markdown]
# ## **Define Model:**

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

gemini_flash: ChatGoogleGenerativeAI = ChatGoogleGenerativeAI(
    model='gemini-1.5-flash',
    temperature=0,
    api_key=GEMINI_API_KEY
)

# %% [markdown]
# # **Example On How To Use/Invoke Gemini:**

# %%
from langchain_core.messages import HumanMessage

msg: HumanMessage = HumanMessage(content="Hello there")
messages:list[HumanMessage] = [msg]
print(messages)
# Out:
# [HumanMessage(content='Hello there', additional_kwargs={}, response_metadata={})]

# %%
response_gemini = gemini_flash.invoke(messages)
response_gemini.content
# Out:
# 'Hello! How can I help you today? \n'
